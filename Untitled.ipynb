# %%
import numpy as np
b = np.load('output/mnist_logreg_lbfgs_retraining-500.npz')
# actual_loss_diffs=actual_loss_diffs, 
#     predicted_loss_diffs_cg=predicted_loss_diffs_cg,
#     predicted_loss_diffs_lissa=predicted_loss_diffs_lissa,
#     indices_to_remove=indices_to_remove

# %%
b['actual_loss_diffs']
print(len(b['actual_loss_diffs']))
# Out:
# 500

# %%
a = np.load('output/adult_all_test_1.npz')
a['actual_loss_diffs']
# print(len(a['actual_loss_diffs']))
# Out:
# array(-4.297495e-05, dtype=float32)

# %%
b1 = np.load('train_svs.npy')
print(len(b1))
print(b1)
# Out:
# 100
# [30204 26905 20904 30932  4899 25251 15330 29553  3488 22817 15787 16145
#  12512 17143 10882 26871 11554 10445 21680 24629  3749  9582 13752 28006
#  18309  5190  7848  1429 16655  7844 28103 13174 21288 30961  9439 10111
#   8231 27353  5731 16669  7575 26167  8666 26072 32181 25666  4672 32221
#  30535 18323 14300 14644 10107    25 10414 23878 19962  8388 31838  6337
#  29025  7100 29963 19108  9315 26981 21124  5118 20290 21818 15193  2527
#  29464  8895  8713 30559 26087 31286 25423  8316 26712 21479 31212 16418
#   2048 12595 23994  7506  1795 18087 28768 18613  7638 29197 30689  9189
#  15945 24576 13295 22391]

# %%
import numpy as np
b2 = np.load('all_train_100_conf_points.npz')
sv = b2['sv']
rs = b2['rs']
list1 = b2['actual_loss']
list2 = b2['influence']
print(sv)
# print(list1)
# print(list2)
list3=[]

for each in list2:
#     print(abs(each))
    list3.append(sum(abs(each)))
list3 = np.array(list3)
print(list3)

list4=[]
for each in list1:
    list4.append(sum(abs(each)))
list4 = np.array(list4)
print(list4-list3)

# np.savez(
# 'all_inf_train_100_conf_points.npz', 
# sv=sv,
# rs=rs,
# influence = list3)
#
# Out:
# [20176  6433 15376   106 17039  4568 21475 23273 15966 15567  7741  1327
#  31512 11178 23957  8897 29187  7186  3593 19944 23011  8656  7377 12679
#  15037  1203 18895 13229 29889 22853  9946  1395  6232  1738  3722 29627
#  15710 28233  2508 25149 16040 29185 13047 12809  7156 22458 18448  8252
#  32214 25416 20091  4880 32084 13201 23840   592 26027 10140 18535 11416
#  16171 28925  3848 12973 25158 12530 16054 26369  1462 22912  3779 30469
#   2128 30936  3493  3513  1774 26121 22120 23126 15143 30306  6590 13951
#   5941 11110  2505 10458 25324 25411  9165 17415   390 20070 23304  9190
#  23990 22087 29549  2282]
# [0.2239524  0.221386   0.18374473 0.18901714 0.1857144  0.18259767
#  0.03358465 0.02051502 0.02958374 0.02794372 0.01723146 0.03145073
#  0.02147266 0.02846796 0.02388058 0.02248114 0.02576913 0.18663543
#  0.12531931 0.01865488 0.01820582 0.03605998 0.0240318  0.0244105
#  0.03489459 0.02066752 0.01766212 0.02623886 0.01814284 0.03337449
# ...

# %%
import numpy as np
b2 = np.load('all_train_100_on_100sv.npz')
sv1 = b2['sv']
rs = b2['rs']
list1 = b2['actual_loss']
list2 = b2['influence']

print(sv1)
# print(list1)
# print(list2)
list3=[]
for each in list2:
#     print(abs(each))
    list3.append(sum(abs(each)))
list3 = np.array(list3)
print(list3)

list4=[]
for each in list1:
    list4.append(sum(abs(each)))
list4 = np.array(list4)
print(list4-list3)
# Out:
# [30204 26905 20904 30932  4899 25251 15330 29553  3488 22817 15787 16145
#  12512 17143 10882 26871 11554 10445 21680 24629  3749  9582 13752 28006
#  18309  5190  7848  1429 16655  7844 28103 13174 21288 30961  9439 10111
#   8231 27353  5731 16669  7575 26167  8666 26072 32181 25666  4672 32221
#  30535 18323 14300 14644 10107    25 10414 23878 19962  8388 31838  6337
#  29025  7100 29963 19108  9315 26981 21124  5118 20290 21818 15193  2527
#  29464  8895  8713 30559 26087 31286 25423  8316 26712 21479 31212 16418
#   2048 12595 23994  7506  1795 18087 28768 18613  7638 29197 30689  9189
#  15945 24576 13295 22391]
# [0.01774349 0.00957362 0.01986183 0.01151636 0.01860849 0.01622734
#  0.01483961 0.01097103 0.01511382 0.01104709 0.0061515  0.01317116
#  0.01495592 0.00792998 0.00630357 0.00633614 0.00686243 0.00621447
#  0.01001474 0.01181382 0.00858549 0.00516639 0.02833271 0.01821578
#  0.00721925 0.01219686 0.00661427 0.00609956 0.01081988 0.01299112
# ...

# %%
print(sv-sv1)
# Out:
# [  9867  -6852  15228 -23836  -1167  -4038  -3805  19241  -2031   3978
#  -22091 -11682   5985   2492  -6628 -22072  26678 -17420  -1895  -6810
#   -2929   2101 -14087   5951  12903 -15010  -7226  13215  -1433   3906
#   -9335  -4562 -18852   -269 -11228  12984   2724  13671 -13124  -7357
#    1812   4044   2423    932 -13095  -1268 -14067  -4587  25505  14162
#   -7659 -10830   8111    960  23159 -23551   3481  -1545   2747    675
#   12789  11841  -7157  -2896  19544 -17324  -2234  -2099 -21894  12801
#    2107   9980 -20560  30382   3078 -28732 -16123  13700   3343  -6266
#   13983  17105 -12799  -1093   -291   -109 -15223  -3493  12908   5149
#    -209   1768  -3203  19964  16118   4622   6951  15654   9373 -13094]

# %%
=== #9 ===
Retraining without train_idx 0 (label 0.0):
0.41342616
0.41346914
Diff in params: 0.0020433085
Loss on test idx with original model    : 0.41346914
Loss on test idx with retrained model   : 0.41342616
Difference in loss after retraining     : -4.297495e-05
Predicted difference in loss (influence): -5.274804393158751e-05

# %%
Retraining without train_idx 0 (label 0.0):
Diff in params: 0.0020708847
Loss on test idx with original model    : 0.41346914
Loss on test idx with retrained model   : 0.41342133
Difference in loss after retraining     : -4.780292510986328e-05
Predicted difference in loss (influence): -0.0007134581632899116

# %%
=== #9 ===
Retraining without train_idx 0 (label 0.0):
0.062061056
0.0620354
Diff in params: 0.010909037
Loss on test idx with original model    : 0.0620354
Loss on test idx with retrained model   : 0.062061056
Difference in loss after retraining     : 2.5656074e-05
Predicted difference in loss (influence): 9.796466637307928e-07

# %%
Retraining without train_idx 0 (label 0.0):
Diff in params: 0.010942501
Loss on test idx with original model    : 0.0620354
Loss on test idx with retrained model   : 0.062065873
Difference in loss after retraining     : 3.0472874641418457e-05
Predicted difference in loss (influence): -0.0014324689071794454

# %%
test_index = 9
[-0.00049444 -0.00049467  0.00049519 -0.00049619 -0.00049738 -0.00049889
 -0.00049931 -0.00049976  0.00050026  0.00050037 -0.00050039 -0.0005006
 -0.00050068 -0.00050112 -0.00050131 -0.00050174 -0.00050238 -0.0005024
 -0.0005035   0.00050367 -0.00050408 -0.00050426 -0.00050478 -0.00050532
  0.0005088  -0.00050886 -0.00051021 -0.00051067 -0.00051072 -0.00051106
 -0.00051301  0.00051463 -0.00051572  0.00051644 -0.00051826 -0.00051867
 -0.0005199  -0.00052002 -0.00052117 -0.00052195 -0.00052235 -0.00052236
 -0.00052292 -0.00052406 -0.00052406 -0.00052498  0.00052789 -0.00052833
 -0.00052862 -0.00052878 -0.00052964 -0.00053001 -0.0005309  -0.00053148
 -0.00053386 -0.00053944 -0.00054254 -0.00054304  0.00054795  0.00054823
 -0.00054961  0.00055026 -0.00055266 -0.00055596 -0.000561   -0.00056132
  0.00056409  0.00056432  0.00056685  0.00056843  0.00057014  0.00057857
  0.00058159 -0.00058165 -0.00058255 -0.00058347  0.00058463 -0.00058992
 -0.00060514 -0.00061579  0.00061601 -0.00061742  0.00062508 -0.00062671
 -0.00064766 -0.00064811 -0.00065023 -0.00066005 -0.00066381 -0.00070068
 -0.00071346 -0.00075888 -0.00127872 -0.00173326 -0.00197716 -0.00199877
 -0.00202584 -0.00202711 -0.00208299 -0.00210451]
======

[10309 13285   148 23942 18206  8606 25280  4032 17997 11589 29832 13009
 25527  8686 30585 30969  2509 24606  5488 26754 25940  6555 21464  6728
  2134 16213 26121    14 31322 18947 19281  5957 25084  2007 14950 16643
 12986 14562 15632 32506 14228 25141 10624 11877 20251 23726 32515 12839
  6709 11254 27750 15710 23973 12241   681 24143 22546 11685 15788 10741
  3382 17084 11005 15869  5614 29854 18288 28468 23356 10111  1672 20489
 22688   554   415 32245 17897 12421 18777 29392  1160 13201 19389 15044
  6232 11219 17728 13951 12416 20262  9374 15647  3593   106  7186  4568
 17039  6433 20176 15376]

# %%
b = np.load('output/all_test.npz')
list1 = b['all_results']
for each in list1:
    print(each)
# print(b['all_results'])
print(len(b['all_results']))
# Out:
# [10309 13285   148 23942 18206  8606 25280  4032 17997 11589 29832 13009
#  25527  8686 30585 30969  2509 24606  5488 26754 25940  6555 21464  6728
#   2134 16213 26121    14 31322 18947 19281  5957 25084  2007 14950 16643
#  12986 14562 15632 32506 14228 25141 10624 11877 20251 23726 32515 12839
#   6709 11254 27750 15710 23973 12241   681 24143 22546 11685 15788 10741
#   3382 17084 11005 15869  5614 29854 18288 28468 23356 10111  1672 20489
#  22688   554   415 32245 17897 12421 18777 29392  1160 13201 19389 15044
#   6232 11219 17728 13951 12416 20262  9374 15647  3593   106  7186  4568
#  17039  6433 20176 15376]
# [10309 13285   148 23942 18206  8606 25280  4032 17997 11589 29832 13009
#  25527  8686 30585 30969  2509 24606  5488 26754 25940  6555 21464  6728
#   2134 16213 26121    14 31322 18947 19281  5957 25084  2007 14950 16643
#  12986 14562 15632 32506 14228 25141 10624 11877 20251 23726 32515 12839
# ...

# %%
for each in list1[0]:
    print(each)
# Out:
# 10309
# 13285
# 148
# 23942
# 18206
# 8606
# 25280
# 4032
# 17997
# 11589
# 29832
# 13009
# 25527
# 8686
# 30585
# 30969
# 2509
# 24606
# 5488
# 26754
# 25940
# 6555
# 21464
# 6728
# 2134
# 16213
# 26121
# 14
# 31322
# 18947
# 19281
# 5957
# 25084
# 2007
# 14950
# 16643
# 12986
# 14562
# 15632
# 32506
# 14228
# 25141
# 10624
# 11877
# 20251
# 23726
# 32515
# 12839
# 6709
# 11254
# 27750
# 15710
# 23973
# 12241
# 681
# 24143
# 22546
# 11685
# 15788
# 10741
# 3382
# 17084
# 11005
# 15869
# 5614
# 29854
# 18288
# 28468
# 23356
# 10111
# 1672
# 20489
# 22688
# 554
# 415
# 32245
# 17897
# 12421
# 18777
# 29392
# 1160
# 13201
# 19389
# 15044
# 6232
# 11219
# 17728
# 13951
# 12416
# 20262
# 9374
# 15647
# 3593
# 106
# 7186
# 4568
# 17039
# 6433
# 20176
# 15376

# %%
l = list([20176  6433 15376   106 17039  4568 21475 23273 15966 15567  7741  1327
 31512 11178 23957  8897 29187  7186  3593 19944 23011  8656  7377 12679
 15037  1203 18895 13229 29889 22853  9946  1395  6232  1738  3722 29627
 15710 28233  2508 25149 16040 29185 13047 12809  7156 22458 18448  8252
 32214 25416 20091  4880 32084 13201 23840   592 26027 10140 18535 11416
 16171 28925  3848 12973 25158 12530 16054 26369  1462 22912  3779 30469
  2128 30936  3493  3513  1774 26121 22120 23126 15143 30306  6590 13951
  5941 11110  2505 10458 25324 25411  9165 17415   390 20070 23304  9190
 23990 22087 29549  2282])
# Out:
#   File "<ipython-input-16-2c15c47a2ba9>", line 1
#     l = list([20176  6433 15376   106 17039  4568 21475 23273 15966 15567  7741  1327
#                         ^
# SyntaxError: invalid syntax

# %%
b = np.load('adult_100_our_computed_vectors2.npz')
print(b.keys())
# Out:
# ['influence', 'idx', 'actual_loss']
